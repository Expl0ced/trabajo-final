# %%
import pandas as pd
import numpy as np
import sqlite3 as db

# %%
data = pd.read_csv("pokemon.csv")
data.head(5)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
data.tail(5)
# Out:
#            abilities  against_bug  against_dark  against_dragon  \
# 796  ['Beast Boost']         0.25           1.0             0.5
# 797  ['Beast Boost']         1.00           1.0             0.5
# 798  ['Beast Boost']         2.00           0.5             2.0
# 799  ['Prism Armor']         2.00           2.0             1.0
# 800   ['Soul-Heart']         0.25           0.5             0.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 796               2.0            0.5            1.0           2.0
# 797               0.5            0.5            2.0           4.0
# 798               0.5            4.0            2.0           0.5
# 799               1.0            1.0            0.5           1.0
# 800               1.0            0.5            1.0           2.0
#
#      against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 796             0.5            1.0  ...              NaN             797
# ...

# %%
data.dtypes
# Out:
# abilities             object
# against_bug          float64
# against_dark         float64
# against_dragon       float64
# against_electric     float64
# against_fairy        float64
# against_fight        float64
# against_fire         float64
# against_flying       float64
# against_ghost        float64
# against_grass        float64
# against_ground       float64
# against_ice          float64
# against_normal       float64
# against_poison       float64
# against_psychic      float64
# against_rock         float64
# against_steel        float64
# against_water        float64
# attack                 int64
# base_egg_steps         int64
# base_happiness         int64
# base_total             int64
# capture_rate          object
# classfication         object
# defense                int64
# experience_growth      int64
# height_m             float64
# hp                     int64
# japanese_name         object
# name                  object
# percentage_male      float64
# ...

# %%
data.count()
# Out:
# abilities            801
# against_bug          801
# against_dark         801
# against_dragon       801
# against_electric     801
# against_fairy        801
# against_fight        801
# against_fire         801
# against_flying       801
# against_ghost        801
# against_grass        801
# against_ground       801
# against_ice          801
# against_normal       801
# against_poison       801
# against_psychic      801
# against_rock         801
# against_steel        801
# against_water        801
# attack               801
# base_egg_steps       801
# base_happiness       801
# base_total           801
# capture_rate         801
# classfication        801
# defense              801
# experience_growth    801
# height_m             781
# hp                   801
# japanese_name        801
# name                 801
# percentage_male      703
# pokedex_number       801
# sp_attack            801
# sp_defense           801
# speed                801
# type1                801
# ...

# %%
"""data = data.drop(['experience_growth', 'japanese_name', 'base_happiness', 'base_egg_steps','capture_rate', 
                  'against_bug', 'against_dark', 'against_dragon', 'against_electric', 'against_fairy', 'against_fight'
                  , 'against_fire', 'against_flying', 'against_ghost', 'against_grass', 'against_ground', 'against_ice'
                 , 'against_normal', 'against_poison', 'against_psychic', 'against_rock', 'against_steel', 'against_water'])"""

data = data.drop(['experience_growth', 'japanese_name', 'base_happiness', 'base_egg_steps','capture_rate'], axis=1)

# %%
data['classfication']
# Out:
# 0             Seed Pokémon
# 1             Seed Pokémon
# 2             Seed Pokémon
# 3           Lizard Pokémon
# 4            Flame Pokémon
#               ...
# 796         Launch Pokémon
# 797    Drawn Sword Pokémon
# 798      Junkivore Pokémon
# 799          Prism Pokémon
# 800     Artificial Pokémon
# Name: classfication, Length: 801, dtype: object

# %%
data.count()
# Out:
# abilities           801
# against_bug         801
# against_dark        801
# against_dragon      801
# against_electric    801
# against_fairy       801
# against_fight       801
# against_fire        801
# against_flying      801
# against_ghost       801
# against_grass       801
# against_ground      801
# against_ice         801
# against_normal      801
# against_poison      801
# against_psychic     801
# against_rock        801
# against_steel       801
# against_water       801
# attack              801
# base_total          801
# classfication       801
# defense             801
# height_m            781
# hp                  801
# name                801
# percentage_male     703
# pokedex_number      801
# sp_attack           801
# sp_defense          801
# speed               801
# type1               801
# type2               417
# weight_kg           781
# generation          801
# is_legendary        801
# dtype: int64

# %%
data = data.rename(columns={'name':'Nombre', 'pokedex_number':'Numero_pokedex', 'classfication':'Clasificacion', 'type1':'Primer_Tipo', 'type2':'Segundo_Tipo',
                            'weight_kg':'Peso', 'height_m':'Altura', 'percentage_male':'Probabilidad_Macho', 'abilities':'Habilidades',
                            'hp':'PS', 'attack':'Ataque', 'defense':'Defensa', 'sp_attack':'Ataque_Especial', 'sp_defense':'Defensa_Especial',
                            'speed':'Velocidad', 'base_total':'Total_Stats', 'against_bug':'Contra_Bicho', 'against_dark':'Contra_Siniestro', 'against_dragon':'Contra_Dragon',
                            'against_electric':'Contra_Electrico', 'against_fairy':'Contra_Hada', 'against_fight':'Contra_Lucha', 'against_fire':'Contra_Fuego',
                            'against_flying':'Contra_Volador', 'against_ghost':'Contra_Fantasma', 'against_grass':'Contra_Planta', 'against_ground':'Contra_Tierra',
                            'against_ice':'Contra_Hielo', 'against_normal':'Contra_Normal', 'against_poison':'Contra_Veneno', 'against_psychic':'Contra_Psiquico',
                            'against_rock':'Contra_Roca', 'against_steel':'Contra_Acero', 'against_water':'Contra_Agua', 'is_legendary':'Legendario', 'generation':'Generacion'
                           })

# %%
nombre=data[(data['Numero_pokedex']>=0)]['Nombre']
num_poke=data[(data['Numero_pokedex']>=0)]['Numero_pokedex']
clasificacion=data[(data['Numero_pokedex']>=0)]['Clasificacion']
tipo1=data[(data['Numero_pokedex']>=0)]['Primer_Tipo']
tipo2=data[(data['Numero_pokedex']>=0)]['Segundo_Tipo']
peso=data[(data['Numero_pokedex']>=0)]['Peso']
altura=data[(data['Numero_pokedex']>=0)]['Altura']
Prop_macho=data[(data['Numero_pokedex']>=0)]['Probabilidad_Macho']
habilidad=data[(data['Numero_pokedex']>=0)]['Habilidades']
hp=data[(data['Numero_pokedex']>=0)]['PS']
attack=data[(data['Numero_pokedex']>=0)]['Ataque']
defense=data[(data['Numero_pokedex']>=0)]['Defensa']
sp_attack=data[(data['Numero_pokedex']>=0)]['Ataque_Especial']
sp_defense=data[(data['Numero_pokedex']>=0)]['Defensa_Especial']
speed=data[(data['Numero_pokedex']>=0)]['Velocidad']
base_total=data[(data['Numero_pokedex']>=0)]['Total_Stats']
bug=data[(data['Numero_pokedex']>=0)]['Contra_Bicho']
dark=data[(data['Numero_pokedex']>=0)]['Contra_Siniestro']
dragon=data[(data['Numero_pokedex']>=0)]['Contra_Dragon']
electric=data[(data['Numero_pokedex']>=0)]['Contra_Electrico']
fairy=data[(data['Numero_pokedex']>=0)]['Contra_Hada']
lucha=data[(data['Numero_pokedex']>=0)]['Contra_Lucha']
fuego=data[(data['Numero_pokedex']>=0)]['Contra_Fuego']
volador=data[(data['Numero_pokedex']>=0)]['Contra_Volador']
fantasma=data[(data['Numero_pokedex']>=0)]['Contra_Fantasma']
planta=data[(data['Numero_pokedex']>=0)]['Contra_Planta']
tierra=data[(data['Numero_pokedex']>=0)]['Contra_Tierra']
hielo=data[(data['Numero_pokedex']>=0)]['Contra_Hielo']
normal=data[(data['Numero_pokedex']>=0)]['Contra_Normal']
veneno=data[(data['Numero_pokedex']>=0)]['Contra_Veneno']
psiquico=data[(data['Numero_pokedex']>=0)]['Contra_Psiquico']
roca=data[(data['Numero_pokedex']>=0)]['Contra_Roca']
acero=data[(data['Numero_pokedex']>=0)]['Contra_Acero']
agua=data[(data['Numero_pokedex']>=0)]['Contra_Agua']
legendary=data[(data['Numero_pokedex']>=0)]['Legendario']
generation=data[(data['Numero_pokedex']>=0)]['Generacion']

pokedex=pd.DataFrame(nombre, columns=['Nombre'])
pokedex
# Out:
#          Nombre
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# ..          ...
# 796  Celesteela
# 797     Kartana
# 798    Guzzlord
# 799    Necrozma
# 800    Magearna
#
# [801 rows x 1 columns]

# %%
prop_hembra=100-data['Probabilidad_Macho']
prop_hembra
# Out:
# 0      11.9
# 1      11.9
# 2      11.9
# 3      11.9
# 4      11.9
#        ...
# 796     NaN
# 797     NaN
# 798     NaN
# 799     NaN
# 800     NaN
# Name: Probabilidad_Macho, Length: 801, dtype: float64

# %%
pokedex=pokedex.assign(Numero_Pokedex=num_poke, Clasificacion=clasificacion, Tipo_1=tipo1, Tipo_2=tipo2, Peso=peso, Altura=altura, 
                      Probabilidad_Macho=Prop_macho, Probabilidad_Hembra=prop_hembra, Habilidades=habilidad, PS=hp, Ataque=attack, Defensa=defense, Ataque_Especial=sp_attack,
                      Defensa_Especial=sp_defense, Velocidad=speed, Total=base_total, Contra_Bicho=bug, Contra_Siniestro=dark, Contra_Dragon=dragon,
                      Contra_Electrico=electric, Contra_Hada=fairy, Contra_Lucha=lucha, Contra_Fuego=fuego, Contra_Volador=volador,
                      Contra_Fantasma=fantasma, Contra_Planta=planta, Contra_Tierra=tierra, Contra_Hielo=hielo, Contra_Normal=normal,
                      Contra_Veneno=veneno, Contra_Psiquico=psiquico, Contra_Roca=roca, Contra_Acero=acero, Contra_Agua=agua, Legendario=legendary,
                      Generacion=generation
                      
                     )
pokedex
# Out:
#          Nombre  Numero_Pokedex        Clasificacion   Tipo_1  Tipo_2   Peso  \
# 0     Bulbasaur               1         Seed Pokémon    grass  poison    6.9
# 1       Ivysaur               2         Seed Pokémon    grass  poison   13.0
# 2      Venusaur               3         Seed Pokémon    grass  poison  100.0
# 3    Charmander               4       Lizard Pokémon     fire     NaN    8.5
# 4    Charmeleon               5        Flame Pokémon     fire     NaN   19.0
# ..          ...             ...                  ...      ...     ...    ...
# 796  Celesteela             797       Launch Pokémon    steel  flying  999.9
# 797     Kartana             798  Drawn Sword Pokémon    grass   steel    0.1
# 798    Guzzlord             799    Junkivore Pokémon     dark  dragon  888.0
# 799    Necrozma             800        Prism Pokémon  psychic     NaN  230.0
# 800    Magearna             801   Artificial Pokémon    steel   fairy   80.5
#
# ...

# %%
pokedex[(pokedex['Tipo_1']=='grass')]['Tipo_1']
# Out:
# 0      grass
# 1      grass
# 2      grass
# 42     grass
# 43     grass
#        ...
# 760    grass
# 761    grass
# 762    grass
# 786    grass
# 797    grass
# Name: Tipo_1, Length: 78, dtype: object

# %%
pokedex.loc[pokedex.Tipo_1=='grass', 'Tipo_1']='Planta'
pokedex.loc[pokedex.Tipo_1=='poison', 'Tipo_1']='Veneno'
pokedex.loc[pokedex.Tipo_1=='fire', 'Tipo_1']='Fuego'
pokedex.loc[pokedex.Tipo_1=='Water', 'Tipo_1']='Agua'
pokedex.loc[pokedex.Tipo_1=='electric', 'Tipo_1']='Electrico'
pokedex.loc[pokedex.Tipo_1=='flying', 'Tipo_1']='Volador'
pokedex.loc[pokedex.Tipo_1=='steel', 'Tipo_1']='Acero'
pokedex.loc[pokedex.Tipo_1=='psychic', 'Tipo_1']='Psiquico'
pokedex.loc[pokedex.Tipo_1=='dark', 'Tipo_1']='Siniestro'
pokedex.loc[pokedex.Tipo_1=='ghost', 'Tipo_1']='Fantasma'
pokedex.loc[pokedex.Tipo_1=='rock', 'Tipo_1']='Roca'
pokedex.loc[pokedex.Tipo_1=='ground', 'Tipo_1']='Tierra'
pokedex.loc[pokedex.Tipo_1=='fight', 'Tipo_1']='Lucha'
pokedex.loc[pokedex.Tipo_1=='fairy', 'Tipo_1']='Hada'
pokedex.loc[pokedex.Tipo_1=='ice', 'Tipo_1']='Hielo'
pokedex.loc[pokedex.Tipo_1=='normal', 'Tipo_1']='Normal'
pokedex.loc[pokedex.Tipo_1=='bug', 'Tipo_1']='Bicho'
pokedex.loc[pokedex.Tipo_1=='dragon', 'Tipo_1']='Dragon'

# %%
pokedex.loc[pokedex.Tipo_2=='grass', 'Tipo_2']='Planta'
pokedex.loc[pokedex.Tipo_2=='poison', 'Tipo_2']='Veneno'
pokedex.loc[pokedex.Tipo_2=='Fire', 'Tipo_2']='Fuego'
pokedex.loc[pokedex.Tipo_2=='Water', 'Tipo_2']='Agua'
pokedex.loc[pokedex.Tipo_2=='electric', 'Tipo_2']='Electrico'
pokedex.loc[pokedex.Tipo_2=='flying', 'Tipo_2']='Volador'
pokedex.loc[pokedex.Tipo_2=='steel', 'Tipo_2']='Acero'
pokedex.loc[pokedex.Tipo_2=='psychic', 'Tipo_2']='Psiquico'
pokedex.loc[pokedex.Tipo_2=='dark', 'Tipo_2']='Siniestro'
pokedex.loc[pokedex.Tipo_2=='ghost', 'Tipo_2']='Fantasma'
pokedex.loc[pokedex.Tipo_2=='rock', 'Tipo_2']='Roca'
pokedex.loc[pokedex.Tipo_2=='ground', 'Tipo_2']='Tierra'
pokedex.loc[pokedex.Tipo_2=='fight', 'Tipo_2']='Lucha'
pokedex.loc[pokedex.Tipo_2=='fairy', 'Tipo_2']='Hada'
pokedex.loc[pokedex.Tipo_2=='ice', 'Tipo_2']='Hielo'
pokedex.loc[pokedex.Tipo_2=='normal', 'Tipo_2']='Normal'
pokedex.loc[pokedex.Tipo_2=='bug', 'Tipo_2']='Bicho'
pokedex.loc[pokedex.Tipo_2=='dragon', 'Tipo_2']='Dragon'

# %%
pokedex=pokedex.fillna('-')
pokedex
# Out:
#          Nombre  Numero_Pokedex        Clasificacion     Tipo_1   Tipo_2  \
# 0     Bulbasaur               1         Seed Pokémon     Planta   Veneno
# 1       Ivysaur               2         Seed Pokémon     Planta   Veneno
# 2      Venusaur               3         Seed Pokémon     Planta   Veneno
# 3    Charmander               4       Lizard Pokémon      Fuego        -
# 4    Charmeleon               5        Flame Pokémon      Fuego        -
# ..          ...             ...                  ...        ...      ...
# 796  Celesteela             797       Launch Pokémon      Acero  Volador
# 797     Kartana             798  Drawn Sword Pokémon     Planta    Acero
# 798    Guzzlord             799    Junkivore Pokémon  Siniestro   Dragon
# 799    Necrozma             800        Prism Pokémon   Psiquico        -
# 800    Magearna             801   Artificial Pokémon      Acero     Hada
#
#       Peso Altura Probabilidad_Macho Probabilidad_Hembra  \
# ...

# %%
pokedex
# Out:
#          Nombre  Numero_Pokedex        Clasificacion     Tipo_1   Tipo_2  \
# 0     Bulbasaur               1         Seed Pokémon     Planta   Veneno
# 1       Ivysaur               2         Seed Pokémon     Planta   Veneno
# 2      Venusaur               3         Seed Pokémon     Planta   Veneno
# 3    Charmander               4       Lizard Pokémon      Fuego        -
# 4    Charmeleon               5        Flame Pokémon      Fuego        -
# ..          ...             ...                  ...        ...      ...
# 796  Celesteela             797       Launch Pokémon      Acero  Volador
# 797     Kartana             798  Drawn Sword Pokémon     Planta    Acero
# 798    Guzzlord             799    Junkivore Pokémon  Siniestro   Dragon
# 799    Necrozma             800        Prism Pokémon   Psiquico        -
# 800    Magearna             801   Artificial Pokémon      Acero     Hada
#
#       Peso Altura Probabilidad_Macho Probabilidad_Hembra  \
# ...

# %%
pokedex.info
# Out:
# <bound method DataFrame.info of          Nombre  Numero_Pokedex        Clasificacion     Tipo_1   Tipo_2  \
# 0     Bulbasaur               1         Seed Pokémon     Planta   Veneno
# 1       Ivysaur               2         Seed Pokémon     Planta   Veneno
# 2      Venusaur               3         Seed Pokémon     Planta   Veneno
# 3    Charmander               4       Lizard Pokémon      Fuego        -
# 4    Charmeleon               5        Flame Pokémon      Fuego        -
# ..          ...             ...                  ...        ...      ...
# 796  Celesteela             797       Launch Pokémon      Acero  Volador
# 797     Kartana             798  Drawn Sword Pokémon     Planta    Acero
# 798    Guzzlord             799    Junkivore Pokémon  Siniestro   Dragon
# 799    Necrozma             800        Prism Pokémon   Psiquico        -
# 800    Magearna             801   Artificial Pokémon      Acero     Hada
#
#       Peso Altura Probabilidad_Macho Probabilidad_Hembra  \
# ...

# %%
pokedex.to_csv("pokedex.csv", index = False)

# %%
conn = db.connect('sssss')
pokedex.to_sql(name='table_name', con=conn)
